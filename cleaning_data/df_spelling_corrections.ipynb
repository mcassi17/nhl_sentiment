# %%
import pandas as pd
import numpy as np
import preprocessor as p
import re
import time

# %%
col_dict = {"hastags": lambda x: x.strip("[]").replace('\'', '').split(", "), "ex_hastags": lambda x: x.strip("[]").replace('\'', '').split(", "), "rt_hastags": lambda x: x.strip("[]").replace('\'', '').split(", "), "exrt_hastags": lambda x: x.strip("[]").replace('\'', '').split(", "), "qt_hastags": lambda x: x.strip("[]").replace('\'', '').split(", "), "exqt_hastags": lambda x: x.strip("[]").replace('\'', '').split(", "), "qtrt_hastags": lambda x: x.strip("[]").replace('\'', '').split(", "), "exqtrt_hastags": lambda x: x.strip("[]").replace('\'', '').split(", "), "mentions": lambda x: x.strip("[]").replace('\'', '').split(", "), "ex_mentions": lambda x: x.strip("[]").replace('\'', '').split(", "), "rt_mentions": lambda x: x.strip("[]").replace('\'', '').split(", "), "exrt_mentions": lambda x: x.strip("[]").replace('\'', '').split(", "), "qt_mentions": lambda x: x.strip("[]").replace('\'', '').split(", "), "exqt_mentions": lambda x: x.strip("[]").replace('\'', '').split(", "), "rtqt_mentions": lambda x: x.strip("[]").replace('\'', '').split(", "), "exqtrt_mentions": lambda x: x.strip("[]").replace('\'', '').split(", "),"team": lambda x: x.strip("[]").replace('\'', '').split(", ")}

# %%
hockey1 = pd.read_csv('/Users/matthewcassi/Documents/nhl_sentiment/team_dfs/remove_tweets.csv', converters=col_dict)

# %%
hockey1 = hockey1.drop('Unnamed: 0', 1)

# %%
hockey1.head()
# Out:
#    index           created_at in_reply_to_screen_name lang  \
# 0      0  2018-01-20 15:34:25                     NaN   en
# 1      1  2018-01-20 15:34:27                     NaN   en
# 2      2  2018-01-20 15:34:28                     NaN   en
# 3      4  2018-01-20 15:34:32             DallasStars   en
# 4      5  2018-01-20 15:34:33                penguins   en
#
#   quoted_status.in_reply_to_screen_name quoted_status.user.screen_name  \
# 0                                   NaN                            NaN
# 1                                   NaN                            NaN
# 2                                   NaN                    HockeyDayMN
# 3                                   NaN                            NaN
# 4                                   NaN                            NaN
#
#   retweeted_status.in_reply_to_screen_name  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# ...

# %%
# row wise function to remove URLs and emojis. takes a row and a column
def remove_urls(row, col):
    # set tweet preprocessing to remove emojis and URLs
    p.set_options(p.OPT.URL, p.OPT.EMOJI)
    
    # remove emojis and URLs from the column
    if type(row[col]) == str:
        return p.clean(row[col])

# %%
hockey1['tweet_1'] = hockey1.apply(remove_urls, axis=1, col='tweet_1')
hockey1['tweet_2'] = hockey1.apply(remove_urls, axis=1, col='tweet_2')

# %%
# tweet_1 Column

# replace the rt with nothing at the front of all tweet_1 columns
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])rt(?![a-z])', '', case=False)
# replace u/U with you
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])u(?![a-z])', 'you', case=False) 
# replace r with are
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])r(?![a-z])', 'are', case=False)
# replace r with are
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])r(?![a-z])', 'are', case=False)
# replace r with are
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])r(?![a-z])', 'are', case=False)
# replace thx with thanks
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])thx(?![a-z])', 'thanks', case=False)
# replace ur with your
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])ur(?![a-z])', 'your', case=False)
# replace bc with because
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])bc(?![a-z])', 'because', case=False)
# replace abt with about
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])abt(?![a-z])', 'about', case=False)
# replace txt with tweet_1
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])txt(?![a-z])', 'tweet_1', case=False)
# replace fb with facebook
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])fb(?![a-z])', 'facebook', case=False)
# replace w with with
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])w(?![a-z])', 'with', case=False)
# replace b4 with before
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])b4(?![a-z])', 'before', case=False)
# replace ast with assist
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])ast(?![a-z])', 'assist', case=False)
# replace tgif with thank god its friday
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])tgif(?![a-z])', 'thank god its friday', case=False)
# replace ily with i love you
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])ily(?![a-z])', 'i love you', case=False)
# replace irl with in real life
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])irl(?![a-z])', 'in real life', case=False)
# replace idk with i dont know
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])idk(?![a-z])', 'i dont know', case=False)
# replace ftw with for the win
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])ftw(?![a-z])', 'for the win', case=False)
# replace idc with i dont care
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])idc(?![a-z])', 'i dont care', case=False)
# replace tbt with throwback thursday
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])tbt(?![a-z])', 'throwback thursday', case=False)
# replace tbh with to be honest
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])tbh(?![a-z])', 'to be honest', case=False)
# replace tfw with that face when
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])tfw(?![a-z])', 'that face when', case=False)
# replace qotd with quote of the day
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])qotd(?![a-z])', 'quote of the day', case=False)
# replace bff with best friends forever
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])bff(?![a-z])', 'best friends forever', case=False)
# replace jk with just kidding
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])jk(?![a-z])', 'just kidding', case=False)
# replace smh with shaking my head
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])smh(?![a-z])', 'shaking my head', case=False)
# replace btw with by the way
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])btw(?![a-z])', 'by the way', case=False)
# replace imo with in my opinion
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])imo(?![a-z])', 'in my opinion', case=False)
# replace imho with in my honest opinion
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])imho(?![a-z])', 'in my honest opinion', case=False)
# replace icymi with in case you missed it
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])icymi(?![a-z])', 'in case you missed it', case=False)
# replace lol with laugh out loud
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])lol(?![a-z])', 'laugh out loud', case=False)
# replace fwiw with for what its worth
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])fwiw(?![a-z])', 'for what its worth', case=False)
# replace afaik with as far as i know
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])afaik(?![a-z])', 'as far as i know', case=False)
# replace gg with good game
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])gg(?![a-z])', 'good game', case=False)
# replace fyi with for your information
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])fyi(?![a-z])', 'for your information', case=False)
# replace num with number
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])num(?![a-z])', 'number', case=False)
# replace omg with oh my god
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])omg(?![a-z])', 'oh my god', case=False)
# replace omfg with oh my fucking god
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])omfg(?![a-z])', 'oh my fucking god', case=False)
# replace asap with as soon as possible
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])asap(?![a-z])', 'as soon as possible', case=False)
# replace til with today i learned
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])til(?![a-z])', 'today i learned', case=False)
# replace lmao with laugh my ass off
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])lmao(?![a-z])', 'laugh my ass off', case=False)
# replace lmfao with laugh my fucking ass off
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])lmfao(?![a-z])', 'laugh my fucking ass off', case=False)
# replace dm with direct message
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])dm(?![a-z])', 'direct message', case=False)
# replace rofl with rolling on the floor laughing
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])rofl(?![a-z])', 'rolling on the floor laughing', case=False)
# replace fomo with fear of missing out
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])fomo(?![a-z])', 'fear of missing out', case=False)
# replace orly with oh really
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])orly(?![a-z])', 'oh really', case=False)
# replace eli5 with explain like im five
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])eli5(?![a-z])', 'explain like im five', case=False)
# replace tmi with too much information
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])tmi(?![a-z])', 'too much information', case=False)
# replace &amp; with and
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace('&amp;', 'and', case=False)
# replace yrs with years
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])yrs(?![a-z])', 'years', case=False)
# replace yr with year
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])yr(?![a-z])', 'year', case=False)
# replace pt with point
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])pt(?![a-z])', 'point', case=False)
# replace pts with points
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])pts(?![a-z])', 'points', case=False)
# replace - with ' '
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])pts(?![a-z])', 'points', case=False)
# replace % with percent
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace('%', 'percent', case=False)
# replace fireav with fire av
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])fireav(?![a-z])', 'fire av', case=False)
# replace vs with versus
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])pts(?![a-z])', 'points', case=False)
# replace ir with injured reserve
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])ir(?![a-z])', 'injured reserve', case=False)
# replace gp with game played
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])gp(?![a-z])', 'game played', case=False)
# replace pts with points
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])pts(?![a-z])', 'points', case=False)
# replace vip with very important person
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])vip(?![a-z])', 'very important person', case=False)
# replace pei with prince edward island
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])pei(?![a-z])', 'prince edward island', case=False)
# replace hof with hall of fame
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])hof(?![a-z])', 'hall of fame', case=False)

# replace msg with madison square garden
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])msg(?![a-z])', 'madison square garden', case=False)
# replace #msg with madison square garden
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace('#msg', 'madison square garden', case=False)
# replace pls with please
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])pls(?![a-z])', 'please', case=False)

# Spelling Corrections
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])tanevhorvath(?![a-z])', 'tanev horvath', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])bigtime(?![a-z])', 'big time', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])overcoaching(?![a-z])', 'over coaching', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])rumour(?![a-z])', 'rumor', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])injuredthis(?![a-z])', 'injured this', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])ppcome(?![a-z])', 'power play come', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])ppg(?![a-z])', 'power play goal', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])againthe(?![a-z])', 'again the', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])goalsawesome(?![a-z])', 'goals awesome', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])laughedjust(?![a-z])', 'laughed just', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])shipem(?![a-z])', 'ship them', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])beleve(?![a-z])', 'believe', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])fuckerz(?![a-z])', 'fucker', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])familywe(?![a-z])', 'family we', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])pointpercent(?![a-z])', 'point percent', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])alrighhhtt(?![a-z])', 'all right', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])hockey1go(?![a-z])', 'hockey1 go', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])midfebruary(?![a-z])', 'middle of february', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])habstv(?![a-z])', 'habs television', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])replys(?![a-z])', 'replays', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])facepalmedand(?![a-z])', 'face palmed and', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])is well(?![a-z])', 'is well', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])andranch(?![a-z])', 'and ranch', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])todaytonight(?![a-z])', 'today tonight', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])fawnwear(?![a-z])', 'fanwear', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])rantanennathan(?![a-z])', 'rantanen nathan', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])soooooscore(?![a-z])', 'so score', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])aweeee(?![a-z])', 'awe', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])wrt(?![a-z])', 'with respect to', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])fleurydont(?![a-z])', 'fleury dont', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])guysplaywithconfidenceguysgo(?![a-z])', 'guys play with confidence guys go', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])thorburnwow(?![a-z])', 'thorburn wow', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])gooooooooooooal(?![a-z])', 'goal', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])leddyboychuk(?![a-z])', 'leddy boychuk', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])ppgoals(?![a-z])', 'power play goals', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])yesterdaywere(?![a-z])', 'yesterday were', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])admittedlywrong(?![a-z])', 'admittedly wrong', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])henrikfails(?![a-z])', 'henrik fails', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])hooooome(?![a-z])', 'home', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])cowardlyand(?![a-z])', 'cowardly and', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])retir(?![a-z])', 'retire', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])mrkruger(?![a-z])', 'mr kruger', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])somethingi(?![a-z])', 'something', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])sanheimmyers(?![a-z])', 'sanheim myers', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])stl(?![a-z])', 'st louis', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])whatwhyhowgoaltender(?![a-z])', 'what why how goaltender', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])exhaustedcheers(?![a-z])', 'exhausted cheers', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])planneed(?![a-z])', 'planned', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])meantimeits(?![a-z])', 'mean time its', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])destroyedutterly(?![a-z])', 'utterly destroyed', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])advantagelets(?![a-z])', 'advantage lets', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])forevermoron(?![a-z])', 'forever moron', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])washrinserepeat(?![a-z])', 'wash rinse repeat', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])helllyah(?![a-z])', 'hell yeah', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])hatelet(?![a-z])', 'hate let', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])lovebruins(?![a-z])', 'love bruins', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])eastatlantic(?![a-z])', 'east atlantic', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])homedressers(?![a-z])', 'home dressers', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])seasonbutttttt(?![a-z])', 'season but', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])chuckin(?![a-z])', 'chucking', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])deadlinemake(?![a-z])', 'deadline make', case=False)

# %%
# Extended Text Column

# replace the rt with nothing at the front of all text columns
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])rt(?![a-z])', '', case=False)
# replace u/U with you
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])u(?![a-z])', 'you', case=False) 
# replace r with are
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])r(?![a-z])', 'are', case=False)
# replace r with are
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])r(?![a-z])', 'are', case=False)
# replace r with are
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])r(?![a-z])', 'are', case=False)
# replace thx with thanks
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])thx(?![a-z])', 'thanks', case=False)
# replace ur with your
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])ur(?![a-z])', 'your', case=False)
# replace bc with because
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])bc(?![a-z])', 'because', case=False)
# replace abt with about
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])abt(?![a-z])', 'about', case=False)
# replace txt with text
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])txt(?![a-z])', 'text', case=False)
# replace fb with facebook
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])fb(?![a-z])', 'facebook', case=False)
# replace w with with
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])w(?![a-z])', 'with', case=False)
# replace b4 with before
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])b4(?![a-z])', 'before', case=False)
# replace ast with assist
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])ast(?![a-z])', 'assist', case=False)
# replace tgif with thank god its friday
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])tgif(?![a-z])', 'thank god its friday', case=False)
# replace ily with i love you
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])ily(?![a-z])', 'i love you', case=False)
# replace irl with in real life
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])irl(?![a-z])', 'in real life', case=False)
# replace idk with i dont know
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])idk(?![a-z])', 'i dont know', case=False)
# replace ftw with for the win
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])ftw(?![a-z])', 'for the win', case=False)
# replace idc with i dont care
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])idc(?![a-z])', 'i dont care', case=False)
# replace tbt with throwback thursday
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])tbt(?![a-z])', 'throwback thursday', case=False)
# replace tbh with to be honest
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])tbh(?![a-z])', 'to be honest', case=False)
# replace tfw with that face when
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])tfw(?![a-z])', 'that face when', case=False)
# replace qotd with quote of the day
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])qotd(?![a-z])', 'quote of the day', case=False)
# replace bff with best friends forever
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])bff(?![a-z])', 'best friends forever', case=False)
# replace jk with just kidding
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])jk(?![a-z])', 'just kidding', case=False)
# replace smh with shaking my head
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])smh(?![a-z])', 'shaking my head', case=False)
# replace btw with by the way
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])btw(?![a-z])', 'by the way', case=False)
# replace imo with in my opinion
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])imo(?![a-z])', 'in my opinion', case=False)
# replace imho with in my honest opinion
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])imho(?![a-z])', 'in my honest opinion', case=False)
# replace icymi with in case you missed it
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])icymi(?![a-z])', 'in case you missed it', case=False)
# replace lol with laugh out loud
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])lol(?![a-z])', 'laugh out loud', case=False)
# replace fwiw with for what its worth
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])fwiw(?![a-z])', 'for what its worth', case=False)
# replace afaik with as far as i know
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])afaik(?![a-z])', 'as far as i know', case=False)
# replace gg with good game
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])gg(?![a-z])', 'good game', case=False)
# replace fyi with for your information
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])fyi(?![a-z])', 'for your information', case=False)
# replace num with number
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])num(?![a-z])', 'number', case=False)
# replace omg with oh my god
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])omg(?![a-z])', 'oh my god', case=False)
# replace omfg with oh my fucking god
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])omfg(?![a-z])', 'oh my fucking god', case=False)
# replace asap with as soon as possible
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])asap(?![a-z])', 'as soon as possible', case=False)
# replace til with today i learned
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])til(?![a-z])', 'today i learned', case=False)
# replace lmao with laugh my ass off
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])lmao(?![a-z])', 'laugh my ass off', case=False)
# replace lmfao with laugh my fucking ass off
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])lmfao(?![a-z])', 'laugh my fucking ass off', case=False)
# replace dm with direct message
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])dm(?![a-z])', 'direct message', case=False)
# replace rofl with rolling on the floor laughing
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])rofl(?![a-z])', 'rolling on the floor laughing', case=False)
# replace fomo with fear of missing out
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])fomo(?![a-z])', 'fear of missing out', case=False)
# replace orly with oh really
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])orly(?![a-z])', 'oh really', case=False)
# replace eli5 with explain like im five
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])eli5(?![a-z])', 'explain like im five', case=False)
# replace tmi with too much information
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])tmi(?![a-z])', 'too much information', case=False)
# replace &amp; with and
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace('&amp;', 'and', case=False)
# replace yrs with years
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])yrs(?![a-z])', 'years', case=False)
# replace yr with year
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])yr(?![a-z])', 'year', case=False)
# replace pt with point
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])pt(?![a-z])', 'point', case=False)
# replace pts with points
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])pts(?![a-z])', 'points', case=False)
# replace - with ' '
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])pts(?![a-z])', 'points', case=False)
# replace % with percent
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace('%', 'percent', case=False)
# replace fireav with fire av
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])fireav(?![a-z])', 'fire av', case=False)
# replace vs with versus
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])pts(?![a-z])', 'points', case=False)
# replace ir with injured reserve
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])ir(?![a-z])', 'injured reserve', case=False)
# replace gp with game played
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])gp(?![a-z])', 'game played', case=False)
# replace pts with points
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])pts(?![a-z])', 'points', case=False)
# replace vip with very important person
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])vip(?![a-z])', 'very important person', case=False)
# replace pei with prince edward island
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])pei(?![a-z])', 'prince edward island', case=False)
# replace hof with hall of fame
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])hof(?![a-z])', 'hall of fame', case=False)

# replace msg with madison square garden
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])msg(?![a-z])', 'madison square garden', case=False)
# replace #msg with madison square garden
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace('#msg', 'madison square garden', case=False)
# replace pls with please
hockey1['tweet_2'] = hockey1['tweet_2'].str.replace(r'(?<![a-z])pls(?![a-z])', 'please', case=False)

# Spelling Corrections
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])tanevhorvath(?![a-z])', 'tanev horvath', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])bigtime(?![a-z])', 'big time', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])overcoaching(?![a-z])', 'over coaching', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])rumour(?![a-z])', 'rumor', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])injuredthis(?![a-z])', 'injured this', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])ppcome(?![a-z])', 'power play come', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])ppg(?![a-z])', 'power play goal', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])againthe(?![a-z])', 'again the', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])goalsawesome(?![a-z])', 'goals awesome', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])laughedjust(?![a-z])', 'laughed just', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])shipem(?![a-z])', 'ship them', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])beleve(?![a-z])', 'believe', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])fuckerz(?![a-z])', 'fucker', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])familywe(?![a-z])', 'family we', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])pointpercent(?![a-z])', 'point percent', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])alrighhhtt(?![a-z])', 'all right', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])hockey1go(?![a-z])', 'hockey1 go', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])midfebruary(?![a-z])', 'middle of february', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])habstv(?![a-z])', 'habs television', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])replys(?![a-z])', 'replays', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])facepalmedand(?![a-z])', 'face palmed and', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])is well(?![a-z])', 'is well', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])andranch(?![a-z])', 'and ranch', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])todaytonight(?![a-z])', 'today tonight', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])fawnwear(?![a-z])', 'fanwear', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])rantanennathan(?![a-z])', 'rantanen nathan', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])soooooscore(?![a-z])', 'so score', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])aweeee(?![a-z])', 'awe', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])wrt(?![a-z])', 'with respect to', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])fleurydont(?![a-z])', 'fleury dont', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])guysplaywithconfidenceguysgo(?![a-z])', 'guys play with confidence guys go', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])thorburnwow(?![a-z])', 'thorburn wow', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])gooooooooooooal(?![a-z])', 'goal', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])leddyboychuk(?![a-z])', 'leddy boychuk', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])ppgoals(?![a-z])', 'power play goals', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])yesterdaywere(?![a-z])', 'yesterday were', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])admittedlywrong(?![a-z])', 'admittedly wrong', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])henrikfails(?![a-z])', 'henrik fails', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])hooooome(?![a-z])', 'home', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])cowardlyand(?![a-z])', 'cowardly and', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])retir(?![a-z])', 'retire', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])mrkruger(?![a-z])', 'mr kruger', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])somethingi(?![a-z])', 'something', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])sanheimmyers(?![a-z])', 'sanheim myers', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])stl(?![a-z])', 'st louis', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])whatwhyhowgoaltender(?![a-z])', 'what why how goaltender', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])exhaustedcheers(?![a-z])', 'exhausted cheers', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])planneed(?![a-z])', 'planned', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])meantimeits(?![a-z])', 'mean time its', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])destroyedutterly(?![a-z])', 'utterly destroyed', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])advantagelets(?![a-z])', 'advantage lets', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])forevermoron(?![a-z])', 'forever moron', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])washrinserepeat(?![a-z])', 'wash rinse repeat', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])helllyah(?![a-z])', 'hell yeah', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])hatelet(?![a-z])', 'hate let', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])lovebruins(?![a-z])', 'love bruins', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])eastatlantic(?![a-z])', 'east atlantic', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])homedressers(?![a-z])', 'home dressers', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])seasonbutttttt(?![a-z])', 'season but', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])chuckin(?![a-z])', 'chucking', case=False)
hockey1['tweet_1'] = hockey1['tweet_1'].str.replace(r'(?<![a-z])deadlinemake(?![a-z])', 'deadline make', case=False)

# %%
def emojis(row, col):
    text = row[col]
    if type(row[col]) == str:
        text = re.sub(r'[^a-zA-Z0-9 _@]+', '', row[col])
    return text

# %%
hockey1['tweet_1'] = hockey1.apply(emojis, axis=1, col='tweet_1')
hockey1['tweet_2'] = hockey1.apply(emojis, axis=1, col='tweet_2')

# %%
hockey1.head()
# Out:
#    index           created_at in_reply_to_screen_name lang  \
# 0      0  2018-01-20 15:34:25                     NaN   en
# 1      1  2018-01-20 15:34:27                     NaN   en
# 2      2  2018-01-20 15:34:28                     NaN   en
# 3      4  2018-01-20 15:34:32             DallasStars   en
# 4      5  2018-01-20 15:34:33                penguins   en
#
#   quoted_status.in_reply_to_screen_name quoted_status.user.screen_name  \
# 0                                   NaN                            NaN
# 1                                   NaN                            NaN
# 2                                   NaN                    HockeyDayMN
# 3                                   NaN                            NaN
# 4                                   NaN                            NaN
#
#   retweeted_status.in_reply_to_screen_name  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# ...

# %%
tweets1 = hockey1[['created_at','hour','tweet_1', 'team']]
tweets2 = hockey1[['created_at','hour','tweet_2', 'team']]

# %%
tweets1.head()
# Out:
#             created_at  hour  \
# 0  2018-01-20 15:34:25    15
# 1  2018-01-20 15:34:27    15
# 2  2018-01-20 15:34:28    15
# 3  2018-01-20 15:34:32    15
# 4  2018-01-20 15:34:33    15
#
#                                              tweet_1     team
# 0  giveaway time retweet and follow to enter if b...    [nyr]
# 1  canadiens gohabsgo habs which canadiens are un...   [habs]
# 2                                lets do that hockey   [wild]
# 3  @dallasstars @ds_foundation ed friggin belfour...  [stars]
# 4   @penguins happy birthday ryan grim reaper reaves   [pens]

# %%
tweets2.head()
# Out:
#             created_at  hour  \
# 0  2018-01-20 15:34:25    15
# 1  2018-01-20 15:34:27    15
# 2  2018-01-20 15:34:28    15
# 3  2018-01-20 15:34:32    15
# 4  2018-01-20 15:34:33    15
#
#                                              tweet_2     team
# 0                                               None    [nyr]
# 1                                               None   [habs]
# 2  happy hockey day minnesota the first game of h...   [wild]
# 3                                               None  [stars]
# 4                                               None   [pens]

# %%
def bool_quotes(row):
    bool_quote = True
    if type(row['tweet_2']) != str:
        bool_quote = False
    return bool_quote

# %%
bool_quotes = tweets2.apply(bool_quotes, axis=1)

# %%
tweets2 = tweets2[bool_quotes]

# %%
tweets2.columns = ['created_at','hour','tweet_1', 'team']

# %%
hockey_tweets = pd.concat([tweets1, tweets2]).reset_index()

# %%
hockey_tweets.head()
# Out:
#    index           created_at  hour  \
# 0      0  2018-01-20 15:34:25    15
# 1      1  2018-01-20 15:34:27    15
# 2      2  2018-01-20 15:34:28    15
# 3      3  2018-01-20 15:34:32    15
# 4      4  2018-01-20 15:34:33    15
#
#                                              tweet_1     team
# 0  giveaway time retweet and follow to enter if b...    [nyr]
# 1  canadiens gohabsgo habs which canadiens are un...   [habs]
# 2                                lets do that hockey   [wild]
# 3  @dallasstars @ds_foundation ed friggin belfour...  [stars]
# 4   @penguins happy birthday ryan grim reaper reaves   [pens]

# %%
hockey_tweets = hockey_tweets.drop('index', 1)

# %%
hockey_tweets.head()
# Out:
#             created_at  hour  \
# 0  2018-01-20 15:34:25    15
# 1  2018-01-20 15:34:27    15
# 2  2018-01-20 15:34:28    15
# 3  2018-01-20 15:34:32    15
# 4  2018-01-20 15:34:33    15
#
#                                              tweet_1     team
# 0  giveaway time retweet and follow to enter if b...    [nyr]
# 1  canadiens gohabsgo habs which canadiens are un...   [habs]
# 2                                lets do that hockey   [wild]
# 3  @dallasstars @ds_foundation ed friggin belfour...  [stars]
# 4   @penguins happy birthday ryan grim reaper reaves   [pens]

# %%
hockey_tweets = hockey_tweets.drop('created_at', 1)

# %%
def non_string(row):
    boolean = False
    if type(row['tweet_1']) == str:
        boolean = True
    return boolean

# %%
boolean = hockey_tweets.apply(non_string, axis=1)
print(sum(boolean), len(hockey_tweets))
hockey_tweets = hockey_tweets[boolean]
# Out:
# 448289 448289

# %%
hockey_tweets = hockey_tweets.dropna(axis='index')

# %%
hockey_tweets.to_csv('spelling_corrections_hash_mentions.csv', header=True)

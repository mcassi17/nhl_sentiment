# %%
import tweepy
import pandas as pd
import numpy as np
import time
from tweepy.streaming import StreamListener
from tweepy import Stream
from tweepy import OAuthHandler

# %%
consumer_key = "B7JP0GJ2Jhv5McoCl33lXGeRE"
consumer_secret = "YgubKfmWoJ9OrdqzeKNhP92Q2XkauH1UHJ5AgQimElpxBb15H5"
access_key = "259554498-m4SVnW2jEUsCtWyGhndMo8I4R4yAv2jqZBi3n3Gn"
access_secret = "n14RTuBqTDUmrdUXXrp0b1CfwxIHrQP6e8177ezTjJogS"

# %%
teams = [['Anaheim Ducks', '@AnaheimDucks', '#LetsGoDucks'],
['Arizona Coyotes', '@ArizonaCoyotes', '#Yotes'],
['Boston Bruins', '@NHLBruins', '#NHLBruins'],
['Buffalo Sabres', '@BuffaloSabres', '#Sabres'],
['Calgary Flames', '@NHLFlames', '#CofRed'],
['Carolina Hurricanes', '@NHLCanes', '#Redvolution'],
['Chicago Blackhawks', '@NHLBlackhawks', '#Blackhawks'],
['Colorado Avalanche', '@Avalanche', '#GoAvsGo'],
['Columbus Blue Jackets', '@BlueJacketsNHL', '#CBJ'],
['Dallas Stars', '@DallasStars', '#GoStars'],
['Detroit Red Wings', '@DetroitRedWings', '#LGRW'],
['Edmonton Oilers', '@EdmontonOilers', '#LetsGoOilers'],
['Florida Panthers', '@FlaPanthers', '#FlaPanthers'],
['Los Angeles Kings', '@LAKings', '#GoKingsGo'],
['Minnesota Wild', '@mnwild', '#mnwild'],
['Montreal Canadiens', '@CanadiensMTL', '#GoHabsGo'],
['Nashville Predators', '@PredsNHL', '#Preds'],
['New Jersey Devils', '@NJDevils', '#NJDevils'],
['New York Islanders', '@NYIslanders', '#Isles'],
['New York Rangers', '@NYRangers', '#NYR'],
['Ottawa Senators', '@Senators', '#Sens'],
['Philadelphia Flyers', '@NHLFlyers', '#LetsGoFlyers'],
['Pittsburgh Penguins', '@penguins', '#LetsGoPens'],
['San Jose Sharks', '@SanJoseSharks', '#SJSharks'],
['St. Louis Blues', '@StLouisBlues', '#AllTogetherNowSTL'],
['Tampa Bay Lightning', '@TBLightning', '#GoBolts'],
['Toronto Maple Leafs', '@MapleLeafs', '#TMLtalk'],
['Vancouver Canucks', '@Canucks', '#Canucks'],
['Vegas Golden Knights', '@GoldenKnights', '#VegasGoesGold'],
['Washington Capitals', '@Capitals', '#ALLCAPS'],
['Winnipeg Jets', '@NHLJets', '#GoJetsGo']]
heading = ['team_name', 'account', 'hashtag']

hockey_twitter = pd.DataFrame(teams, co=heading)

# %%
hockey_twitter.head()
# Out:
#          team_name          account       hashtag
# 0    Anaheim Ducks    @AnaheimDucks  #LetsGoDucks
# 1  Arizona Coyotes  @ArizonaCoyotes        #Yotes
# 2    Boston Bruins       @NHLBruins    #NHLBruins
# 3   Buffalo Sabres   @BuffaloSabres       #Sabres
# 4   Calgary Flames       @NHLFlames       #CofRed

# %%
ducks = ['19835035','#ducks','83889292','323957028']
yotes = ['20006987','#yotes','20814549','160198689']
bruins = ['44166798','#bruins', '27371493','1323171300','1202580732']
sabres = ['22536395','#sabres','17059046','29076876']
flames = ['27487343','#flames','24728459','252450271','1327709479']
canes = ['19673276','#canes','#hurricanes','768208989985406976','996321888']
hawks = ['14498484','#blackhawks','757214310','29130013','398685554']
avs = ['26577824','#goavsgo','#avs','77664338', '258467963', '25867420']
jackets = ['23783692','#CBJ', '21094092','1471201632']
stars = ['29304837','#gostars', '18395755','31336683','21713551', '23262329']
wings = ['16826656','#wings','#lgrw', '50778210', '995887987']
oilers = ['15361389','#LetsGoOilers', '18085017', '54653547']
panthers = ['29460627','#FlaPanthers', '16779721','836554471', '718966627795144704']
kings = ['19013887','#gokingsgo', '543794087','78975783','1345003530']
wild = ['17374906','#mnwild','16426969', '842457486']
habs = ['19678937','#habs','196380056','996629102','18813484']
preds = ['29264626','#Preds','2252615174','995801564']
devils = ['40878677','#NJDevils','3409410898','1092393595','418252505','#devils']
isles = ['16651754','#Isles','17080778','1340265464']
rangers = ['20264905','#nyr','#rangers','2906088671','2777377987','69144104','106179198','914833453652332550','65502374']
sens = ['43885373', '#sens','27501156','46479891','1419131304']
flyers = ['19618527', '#flyers','30231066','20225770']
pens = ['15020865','#LetsGoPens','17064814','19247955','1666208815','#pens']
sharks = ['27961547', '#SJSharks','23126410','1116078104', '#sharks']
blues = ['22976125', '#stlblues', '19993234', '989098927', '21165851']
light = ['28173550', '#bolts','43922115','382833546','#GoBolts']
leafs = ['55594930', '#TMLtalk','22809756','3003688642','1400741359','1429135357','#leafs']
nucks = ['17093604', '29784625', '64220843', '#Canucks']
knights = ['743155992997691392', '#GoldenKnights','3406125914','865262835265359873']
caps = ['14801539', '#caps','#allcaps','90557401','19333454','16498112', '#caps']
jets = ['308556440','#GoJetsGo','#winnipegjets','311783466', '1240795740','18198635']

# %%
#canucks
class listener(StreamListener):

    def on_data(self, data):
        try:
            file = open('hockeytweets.csv', 'a')
            #file = open('duckstweets.csv', 'a')
            #file = open('yotestweets.csv', 'a')
            #file = open('bruinstweets.csv', 'a')
            #file = open('sabrestweets.csv', 'a')
            #file = open('flamestweets.csv', 'a')
            #file = open('canestweets.csv', 'a')
            #file = open('hawkstweets.csv', 'a')
            #file = open('avstweets.csv', 'a')
            #file = open('jacketstweets.csv', 'a')
            #file = open('starstweets.csv', 'a')
            #file = open('wingstweets.csv', 'a')
            #file = open('oilerstweets.csv', 'a')
            #file = open('pantherstweets.csv', 'a')
            #file = open('kingstweets.csv', 'a')
            #file = open('wildtweets.csv', 'a')
            #file = open('habstweets.csv', 'a')
            #file = open('predstweets.csv', 'a')
            #file = open('devilstweets.csv', 'a')
            #file = open('islesstweets.csv', 'a')
            #file = open('rangerstweets.csv', 'a')
            #file = open('senstweets.csv', 'a')
            #file = open('flyerstweets.csv', 'a')
            #file = open('penstweets.csv', 'a')
            #file = open('sharkstweets.csv', 'a')
            #file = open('bluestweets.csv', 'a')
            #file = open('lighttweets.csv', 'a')
            #file = open('leafstweets.csv', 'a')
            #file = open('nuckstweets.csv', 'a')
            #file = open('knightstweets.csv', 'a')
            #file = open('capstweets.csv', 'a')
            #file = open('duckstweets.csv', 'a')
            file.write(data)
            file.write('\n')
            file.close()
            return(True)
        except BaseException as e:
            print('failed ondata: ' + str(e))
            time.sleep(5)
            
    def on_error(self, status):
        print(status)

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)

twitterStream = Stream(auth, listener())

##Everything
twitterStream.filter(track=['#ducks','#yotes','#bruins','#sabres','#flames','#canes','#hurricanes','#blackhawks','#avs','#cbj','#stars','#gostars','#wings','#lgrw','#oilers','#flapanthers','#gokingsgo','#mnwild','#habs','#preds','#njdevils','#isles','#nyr','#sens','#flyers','#pens','#sjsharks','#sharks','#stlblues','#bolts','#leafs','#canucks','#goldenknights','#caps','#allcaps','#winnipegjets'], follow=['83889292','323957028','20814549','160198689','27371493','1323171300','1202580732','17059046','29076876','24728459','252450271','1327709479','768208989985406976','996321888','757214310','29130013','398685554','77664338', '258467963', '25867420','21094092','1471201632','18395755','31336683','21713551', '23262329','50778210', '995887987','18085017','54653547','16779721','836554471','718966627795144704','543794087','78975783','1345003530','16426969','842457486','196380056','996629102','18813484','2252615174','995801564','3409410898','1092393595','418252505','17080778','1340265464','2906088671','2777377987','69144104','106179198','914833453652332550','65502374','27501156','46479891','1419131304','30231066','20225770','17064814','19247955','1666208815','23126410','1116078104','19993234', '989098927','21165851','43922115','382833546','22809756','3003688642','1400741359','1429135357','29784625','64220843','3406125914','865262835265359873','90557401','19333454','16498112','311783466','1240795740','18198635','19835035','20006987','44166798','22536395''27487343','19673276','14498484','26577824','23783692','29304837','16826656','15361389','29460627','19013887','17374906','19678937','29264626','40878677','16651754''20264905','43885373','19618527','15020865','27961547','22976125','28173550','55594930','17093604','743155992997691392','14801539','308556440'], languages=['en'])

#twitterStream.filter(track=['@AnaheimDucks','#ducks'])
#twitterStream.filter(track=['@ArizonaCoyotes','#yotes'])
#twitterStream.filter(track=['@NHLBruins','#bruins'])
#twitterStream.filter(track=['@BuffaloSabres','#sabres'])
#twitterStream.filter(track=['@NHLFlames','#flames'])
#twitterStream.filter(track=['@NHLCanes','#canes','#hurricanes'])                           
#twitterStream.filter(track=['@NHLBlackhawks','#blackhawks'])
#twitterStream.filter(track=['@Avalanche','#avs'])
#twitterStream.filter(track=['@BlueJacketsNHL','#cbj'])
#twitterStream.filter(track=['@DallasStars','#stars','#gostars'])
#twitterStream.filter(track=['@DetroitRedWings','#wings','#lgrw'])
#twitterStream.filter(track=['@EdmontonOilers','#oilers'])
#twitterStream.filter(track=['@FlaPanthers','#FlaPanthers'])
#twitterStream.filter(track=['@LAKings','#gokingsgo'])
#twitterStream.filter(track=['@mnwild','#mnwild'])
#twitterStream.filter(track=['@CanadiensMTL','#habs'])
#twitterStream.filter(track=['@PredsNHL','#preds'])
#twitterStream.filter(track=['@NJDevils','#njdevils'])
#twitterStream.filter(track=['@NYIslanders','#isles'])
#twitterStream.filter(track=['@NYRangers','#nyr'])
#twitterStream.filter(track=['@Senators','#sens'])
#twitterStream.filter(track=['@NHLFlyers','#flyers'])
#twitterStream.filter(track=['@penguins','#pens'])
#twitterStream.filter(track=['@SanJoseSharks','#SJSharks','#sharks'])
#twitterStream.filter(track=['@StLouisBlues','#stlblues'])
#twitterStream.filter(track=['@TBLightning','#bolts'])
#twitterStream.filter(track=['@MapleLeafs','#leafs'])
#twitterStream.filter(track=['@Canucks','#canucks'])
#twitterStream.filter(track=['@GoldenKnights','#goldenknights'])
#twitterStream.filter(track=['@capitals','#caps','#allcaps'])
#twitterStream.filter(track=['@NHLJets','#winnipegjets','#gojetsgo'])
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# /anaconda/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# /anaconda/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# ...

# %% [markdown]
# 2906088671 => @HockeyStatMiner
# 2777377987 => @VallysView
# 69144104 => @TomUrtzJr
# 106179198 => @BlueSeatBlogs
# 914833453652332550 => @BlueshirtBanter
# 65502374 => @AdamZHerman
# 323957028 => @PucksofaFeather
# 83889292 => @AnaheimCalling
# 160198689 => @HowlinHockey
# 20814549 => @Five4Howling
# 1202580732 => @DaysofYOrr
# 1323171300 => @Causeway_Crowd
# 27371493 => @cupofchowdah
# 29076876 => @sabrenoise
# 17059046 => @diebytheblade
# 1327709479 => @Flame_4_Thought
# 252450271 => @MatchsticksCGY
# 24728459 => @FlamesNation
# 996321888 => @CardiacCane
# 768208989985406976 => @CanesCountry
# 398685554 => @Blackhawk_Up
# 29130013 => @The1Tab
# 757214310 => @2ndCityHockey
# 25867420 => @MileHighHockey
# 258467963 => @MHSticking
# 77664338 => @BrgBrigadeKevin
# 1471201632 => @UnionAndBlue
# 21094092 => @cbjcannon
# 23262329 => @Classlicity
# 21713551 => @StarsInsideEdge
# 31336683 => @BlackoutDallas
# 18395755 => @DefendingBigD
# 995887987 => @OctopusThrower_
# 50778210 => @wingingitmotown
# 54653547 => @CopperandBlue
# 18085017 => @OilersNation
# 718966627795144704 => @sun_puck
# 836554471 => @FanSidedTheRat
# 16779721 => @LitterBoxCats
# 1345003530 => @RinkRoyalty
# 78975783 => @lakingsinsider
# 543794087 => @JFTC_Kings
# 842457486 => @FSGonePuckWild
# 16426969 => @hockeywildernes
# 18813484 => @AllHabs
# 996629102 => @FSAWinningHabit
# 196380056 => @HabsEOTP
# 995801564 => @PredlinesNSH
# 2252615174 => @OnTheForecheck
# 418252505 => @DevilsArmyBlog
# 1092393595 => @pitchforkedpuck
# 3409410898 => @AATJerseyBlog
# 1340265464 => @eyesonislesFS
# 17080778 => @LHHockey
# 1419131304 => @SenShot_FS
# 46479891 => @SensChirp
# 27501156 => @silversevensens
# 20225770 => @BroadStHockey
# 30231066 => @BroadStreetBuzz
# 1666208815 => @PensLabyrinthFS
# 19247955 => @Pensblog
# 17064814 => @Pensburgh
# 1116078104 => @BladesofTeal
# 23126410 => @fearthefin
# 21165851 => @StLouisGameTime
# 989098927 => @BleedinBlueFS
# 19993234 => @FrozenNotes
# 382833546 => @BoltsByTheBay
# 43922115 => @RawCharge
# 1429135357 => @TLNdc
# 1400741359 => @EditorinLeaf
# 3003688642 => @PPPLeafs
# 22809756 => @LeafsNews
# 64220843 => @sportsnetmurph
# 29784625 => @CanucksArmy
# 865262835265359873 => @knightsonice
# 3406125914 => @SinBinVegas
# 16498112 => @JapersRink
# 19333454 => @VogsCaps
# 90557401 => @russianmachine
# 18198635 => @IllegalCurve
# 1240795740 => @NHLJetsNation
# 311783466 => @arcticicehockey
